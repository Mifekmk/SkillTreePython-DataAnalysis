# %% [markdown]
# <a href="https://colab.research.google.com/github/Mifekmk/SkillTreePython-DataAnalysis/blob/main/ch02_01_Matplotib%EA%B8%B0%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ch02.01. Matplotlib 기본**
#
# ```
# 이 노트는 `Matplotlib Tutorial: 파이썬으로 데이터 시각화하기` 책을 바탕으로 공부하고 정리한 것임을 밝힙니다.
# ```
#
# * 책 소개
# >  [Matplotlib Tutorial: 파이썬으로 데이터 시각화하기](https://wikidocs.net/book/5011)
# >
#
#
# * 라이브러리 소개
#   > matplotlib

# %% [markdown]
# ## **01. 기본 사용**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92071/basics_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 그래프 그리기**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4])
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], marker='o', color='g') # plot() 함수는 리스트의 값들이 y 값들이라고 가정하고, x값 [0,1,2,3]을 자동으로 만들어냅니다.
plt.show()                                 # x=[0,1,2,3...]은 디폴트 값입니다.

# %% [markdown]
# ```
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# plt.show()
# ```

# %%
plt.plot([1,2,3,4],[1,4,9,16], marker='s')
# plot() 함수는 다양한 기능을 포함하고 있어서, 임의의 개수의 인자를 받을 수 있습니다.
plt.show()

# %% [markdown]
# ### **| 스타일 지정하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# plt.axis([0, 6, 0, 20])
# plt.show()
# ```

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro-') # x축, y축
plt.axis([0.9,4.1,0.1,17])
# matplotlib.pyplot 모듈의 axis() 함수를 이용해서 축의 범위[xmin, xmax, ymin, ymax]를 지정했습니다.
plt.show()

# %% [markdown]
# ### **| 여러 개의 그래프 그리기**
#
#
# ```
# # 200ms 간격으로 균일하게 샘플된 시간
# t = np.arange(0., 5., 0.2)
#
# # 빨간 대쉬, 파란 사각형, 녹색 삼각형
# plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0., 5., 0.2)
plt.plot(t,t, 'r--', t,t**2,'bs', t,t**3,'g^')
plt.show()
# Matplotlib 에서는 일반적으로 Numpy 어레이를 이용하게 되는데,
# 사실 Numpy 어레이를 사용하지 않더라도 모든 시퀀스는 내부적으로 Numpy 어레이로 변환됩니다.
# 다양한 스타일을 갖는 여러 개의 곡선을 하나의 그래프로 나타냅니다.

# %% [markdown]
# ## **02. 숫자 입력하기**
#
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137321/basic_plot_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([2, 3, 5, 10])
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([2,3,5,10]) 
# plot(np.array([2,3,5,10])와 같이 파이썬 튜플 또는 Numpy 어레이의 형태로도 데이터를 입력할 수 있습니다.
plt.show()

# %% [markdown]
# ### **| x, y 값 입력**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.show()
# ```

# %%
plt.plot([1,2,3,4],[2,3,5,10], marker='s',color='r')
plt.show()

# %% [markdown]
# ### **| 레이블이 있는 데이터 사용하기**
#
#
#
#
# ```
# data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}
#
# plt.plot('data_x', 'data_y', data=data_dict)
# plt.show()
# ```

# %%
data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}
# 파이썬 딕셔너리와 같이 레이블이 있는 데이터를 그래프로 나타낼 수 있습니다.
plt.plot('data_x', 'data_y', data=data_dict, marker='s')
# plot() 함수에 데이터의 레이블(딕셔너리의 키)를 입력해주고, data 파라미터에 딕셔너리를 지정해줍니다.
plt.show()

# %% [markdown]
# ## **03. 축 레이블 설정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92081/set_label_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# plt.xlabel('X-Label')
# plt.ylabel('Y-Label')
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16],marker='s')
plt.xlabel('X-Label') # xlabel()
plt.ylabel('Y-Label') # ylabel() 함수를 사용해서 그래프의 축에 레이블을 표시합니다.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-201-6132b14de3d8> in <module>()
#       2
#       3 plt.plot([1, 2, 3, 4], [1, 4, 9, 16],marker='s')
# ----> 4 plt.xlabel('X-Label') # xlabel()
#       5 plt.ylabel('Y-Label') # ylabel() 함수를 사용해서 그래프의 축에 레이블을 표시합니다.
#       6 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ### **| 여백 지정**
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', labelpad=15)
# plt.ylabel('Y-Axis', labelpad=20)
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15) # labelpad로 x축 레이블에 대해서 15pt
plt.ylabel('Y-Axis', labelpad=20) # labelpad로 y축 레이블에 대해서 20pt
plt.show()

# %% [markdown]
# ### **| 폰트 설정하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', labelpad=15, fontdict={'family': 'serif', 'color': 'b', 'weight': 'bold', 'size': 14})
# plt.ylabel('Y-Axis', labelpad=20, fontdict={'family': 'fantasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=18, fontdict={'family': 'fantasy', 'color': 'b', 'weight': 'bold', 'size': 20})
plt.ylabel('Y-Axis', labelpad=20, fontdict={'family': 'fantasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
plt.show()

# %% [markdown]
# ```
# font1 = {'family': 'serif',
#          'color': 'b',
#          'weight': 'bold',
#          'size': 14
#          }
#
# font2 = {'family': 'fantasy',
#          'color': 'deeppink',
#          'weight': 'normal',
#          'size': 'xx-large'
#          }
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
# plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
# plt.show()
# ```

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
plt.show()

# %% [markdown]
# ### **| 위치 지정하기**
#
#
# `xlabel()` 함수의 `loc` 파라미터는 X축 레이블의 위치를 지정합니다. `({‘left’, ‘center’, ‘right’})`
#
# `ylabel()` 함수의 `loc` 파라미터는 Y축 레이블의 위치를 지정합니다. `({‘bottom’, ‘center’, ‘top’})`
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', loc='right')
# plt.ylabel('Y-Axis', loc='top')
# plt.show()
# ```

# %%
plt.plot([1])

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')    # Matplotlib 3.3 이후 버전부터 적용
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ## **04. 범례 표시하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137778/set_legend_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.legend()
#
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

plt.show()

# %% [markdown]
# ### **| 위치 지정하기**
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc=(0.0, 0.0))
# # plt.legend(loc=(0.5, 0.5))
# plt.legend(loc=(1.0, 1.0))
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
#plt.legend(loc=(0.0, 0.0))
#plt.legend(loc=(0.5, 0.5))
plt.legend(loc=(0.7, 0.3))

plt.show()

# %% [markdown]
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.legend(loc='lower right')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### **| 열 개수 지정하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc='best')          # ncol = 1
# plt.legend(loc='best', ncol=2)    # ncol = 2
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')          # ncol = 1
plt.legend(loc='best', ncol=2)    # ncol = 2
# ncol은 범례에 표시될 텍스트의 열의 개수를 지정합니다.
plt.show()

# %% [markdown]
# ### **| 폰트 크기 지정하기**
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc='best')
# plt.legend(loc='best', ncol=2, fontsize=14)
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14)

plt.show()

# %% [markdown]
# ### **| 범례 테두리 꾸미기**
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc='best')
# plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)

plt.show()

# %% [markdown]
# ## **05. 축 범위 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92082/axis_range_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용 - `xlim(), ylim()`**
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
# plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]
#
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]

plt.show()

# %% [markdown]
# ### **| 기본 사용: `axis()`**
#
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10],marker='o')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])  
# X, Y축의 범위: [xmin, xmax, ymin, ymax]

plt.show()

# %% [markdown]
# ### **| 옵션 지정하기**
#
# ```
# 'on' | 'off' | 'equal' | 'scaled' | 'tight' | 'auto' | 'normal' | 'image' | 'square'
# ```
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.axis('square')
# plt.axis('scaled')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.axis('square')
plt.axis('scaled')

plt.show()

# %% [markdown]
# ### **| 축 범위 얻기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# x_range, y_range = plt.xlim(), plt.ylim()
# print(x_range, y_range)
#
# axis_range = plt.axis('scaled')
# print(axis_range)
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], marker='s')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range) # [x_min, x_max, y_min, y_max]

plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %% [markdown]
# ## **06. 선 종류 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137791/set_linestyle_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# | 표현 | 종류 |
# |--|--|
# |`-`  | Solid |
# | `--` |Dashed|
# |`:`|Dotted|
# |`-.` |Dash-dot|
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
# plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
# plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
# plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=4)
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.show()

# %% [markdown]
# ### **| linestyle 지정하기**
#
#
# | 표현 | 종류 |
# |--|--|
# |`solid`  | Solid |
# | `dashed` |Dashed|
# |`dotted`|Dotted|
# |`dashdot` | Dash-dot|
#
# ```
# plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
# plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
# plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
# plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=4)
# plt.tight_layout()
# plt.show()
# ```

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
# plt.plot() 안에 linestyle을 정해주었습니다.
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **| 튜플 사용하기**
#
#
# ```
# plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))')
# plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))')
# plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))')
# plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=2)
# plt.tight_layout()
# plt.show()
# ```

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))')
plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))')
plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))')
plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **| 선 끝 모양 지정하기**
#
#
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=10,
#       solid_capstyle='butt', color='C0', label='solid+butt')
# plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
#       solid_capstyle='round', color='C0', label='solid+round')
#
# plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
#       dash_capstyle='butt', color='C1', label='dashed+butt')
# plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
#       dash_capstyle='round', color='C1', label='dashed+round')
#
#
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=2)
# plt.tight_layout()
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=10,
      solid_capstyle='butt', color='C0', label='solid+butt')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
      solid_capstyle='round', color='C0', label='solid+round')

plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
      dash_capstyle='butt', color='C1', label='dashed+butt')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
      dash_capstyle='round', color='C1', label='dashed+round')


plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **07. 마커 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92083/set_marker_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### **| 선/마커 동시에 나타내기**
#
#
# ```
# # plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.show()
# ```

# %%
#plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### **| 선/마커 표시 형식**
#
# | 표현 | 종류 |
# |--|--|
# |`b`  | blue markers with default shape |
# | `ro` |red circles|
# |`g-`|green solid line|
# |`k^` | balck triangle_up markers connected by a dotted line|
#
#
# ```
# # plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.show()
# ```

# %%
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### **| marker 파라미터 사용하기**
#
# ```
# plt.plot([4, 5, 6], marker="H")
# plt.plot([3, 4, 5], marker="d")
# plt.plot([2, 3, 4], marker="x")
# plt.plot([1, 2, 3], marker=11)
# plt.plot([0, 1, 2], marker='$Z$')
# plt.show()
# ```

# %%
plt.plot([4, 5, 6], marker="H")
plt.plot([3, 4, 5], marker="d")
plt.plot([2, 3, 4], marker="x")
plt.plot([1, 2, 3], marker=11)
plt.plot([0, 1, 2], marker='$Z$')
plt.show()

# %% [markdown]
# ---
# ## **08. 색상 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_00.png width=500>
# </p>

# %% [markdown]
# ### **| 포맷 문자열 사용하기**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
# plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
# plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### **| `color` 키워드 인자 사용하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
# plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='violet')
# plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='violet')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### **| Hex code 사용하기**
#
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62',
#          marker='o', linestyle='--')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62',
         marker='o', linestyle='--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### **| Matplotlib 색상들**

# %% [markdown]
# * **Cycler 색상**
#
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_06.png width=300>
# </p>

# %% [markdown]
# * **기본 색상**
#
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_04.PNG width=500>
# </p>

# %% [markdown]
# * **Tableau 색상**
#
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_07.PNG width=450>
# </p>

# %% [markdown]
# * **CSS 색상**
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_05.PNG width=550>
# </p>

# %% [markdown]
# ## **09. 그래프 영역 채우기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92086/fill_region_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용 - fill_between()**
#
#
# ```
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4]
# y = [2, 3, 5, 10]
#
# plt.plot(x, y)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill_between(x[1:3], y[1:3], alpha=0.5)
#
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y[1:3], alpha=0.5)
# fill_between()
plt.show()

# %% [markdown]
# ### **| 기본 사용 - fill_betweenx()**
#
#
#
# ```
# x = [1, 2, 3, 4]
# y = [2, 3, 5, 10]
#
# plt.plot(x, y)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)
# fill_betweenx()

plt.show()

# %% [markdown]
# ### **| 두 그래프 사이 영역 채우기**
#
#
# ```
# x = [1, 2, 3, 4]
# y1 = [2, 3, 5, 10]
# y2 = [1, 2, 4, 8]
#
# plt.plot(x, y1)
# plt.plot(x, y2)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)
# fill_between
plt.show()

# %% [markdown]
# ### **| 다각형 영역 채우기 - fill()**
#
# ```
# x = [1, 2, 3, 4]
# y1 = [2, 3, 5, 10]
# y2 = [1, 2, 4, 8]
#
# plt.plot(x, y1)
# plt.plot(x, y2)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgray', alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# ## **10. 축 스케일 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137913/axis_scale_00.png width=500>
# </p>

# %% [markdown]
# ### **| X축 스케일 지정하기**
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.linspace(-10, 10, 100)
# y = x ** 3
#
# plt.plot(x, y)
# plt.xscale('symlog')
#
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
y = x ** 3

plt.plot(x, y)
plt.xscale('symlog')

plt.show()

# %% [markdown]
# ### **| Y축 스케일 지정하기**
#
# ```
# x = np.linspace(0, 5, 100)
# y = np.exp(x)
#
# plt.plot(x, y)
# # plt.yscale('linear')
# plt.yscale('log')
#
# plt.show()
# ```

# %%
x = np.linspace(0, 5, 100)
y = np.exp(x)

plt.plot(x, y)
# plt.yscale('linear')
plt.yscale('log')

plt.show()

# %% [markdown]
# ## **11. 여러 곡선 그리기**
#
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92087/multiple_curves_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
plt.show()

# %% [markdown]
# ### **| 스타일 지정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.show()

# %% [markdown]
# ## **12. 그리드 설정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92088/set_grid_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.grid(True)
#
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True) # 그래프의 x,y축에 대해 그리드가 표시됩니다.

plt.show()

# %% [markdown]
# ### **| 축 지정하기**
#
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# plt.grid(True, axis='y')
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True, axis='y')

plt.show()

# %% [markdown]
# ### **| 스타일 설정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')

plt.show()

# %% [markdown]
# ## **13. 눈금 표시하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92089/set_ticks_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
#
# ```
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# plt.xticks([0, 1, 2])
# plt.yticks(np.arange(1, 6))
#
# plt.show()
# ```

# %%
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))

plt.show()

# %% [markdown]
# ### **| 눈금 레이블 지정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
# plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.show()

# %% [markdown]
# ### **| 눈금 스타일 설정하기**
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
# plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))
#
# plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=14, labelcolor='green', top=True)
# plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='r')
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=14, labelcolor='green', top=True)
plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='r')

plt.show()

# %% [markdown]
# ## **14. 타이틀 설정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92090/set_title_00.png width=450>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# plt.title('Graph Title')
#
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title')

plt.show()

# %% [markdown]
# ### **| 위치와 오프셋 지정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# plt.title('Graph Title', loc='right', pad=20)
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)

plt.show()

# %% [markdown]
# ### **| 폰트 지정하기**
#
#
#
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# plt.title('Graph Title', loc='right', pad=20)
#
# title_font = {
#     'fontsize': 16,
#     'fontweight': 'bold'
# }
# plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

plt.show()

# %% [markdown]
# ### **| 타이틀 얻기**
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# title_right = plt.title('Graph Title', loc='right', pad=20)
#
# title_font = {
#     'fontsize': 16,
#     'fontweight': 'bold'
# }
# title_left = plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)
#
# print(title_left.get_position())
# print(title_left.get_text())
#
# print(title_right.get_position())
# print(title_right.get_text())
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
title_right = plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
title_left = plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

print(title_left.get_position())
print(title_left.get_text())

print(title_right.get_position())
print(title_right.get_text())

plt.show()
# Out:
# (0.0, 1.0)
# Graph Title
# (1.0, 1.0)
# Graph Title

# %% [markdown]
# ## **29. 이미지 저장하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92090/set_title_00.png width=450>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
#
#
# ```
# import numpy as np
# import matplotlib.pyplot as plt
#
# x1 = np.linspace(0.0, 5.0)
# x2 = np.linspace(0.0, 2.0)
#
# y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
# y2 = np.cos(2 * np.pi * x2)
#
# plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
# plt.plot(x1, y1, 'o-')
# plt.title('1st Graph')
# plt.ylabel('Damped oscillation')
#
# plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
# plt.plot(x2, y2, '.-')
# plt.title('2nd Graph')
# plt.xlabel('time (s)')
# plt.ylabel('Undamped')
#
# plt.tight_layout()
# # plt.show()
# plt.savefig('savefig_default.png')
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
# plt.show()
plt.savefig('savefig_default.png')

# %% [markdown]
# ## 문제풀이
# ---

# %% [markdown]
# ####**예제 01**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_01`로 저장하세요
#
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-1.PNG?raw=true width=400>
# </p>

# %%
plt.plot([0,1,2,4,8,9], color='orange', marker='o')
plt.plot([0,10,5,4,2,1], color='blue', marker='o')
plt.axis([1.0,5.5,0.8,10.5])
plt.savefig('ch0201_01.png')

# %% [markdown]
# ####**예제 02**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_02`로 저장하세요
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-2.PNG?raw=true width=400>
# </p>

# %%
x = [1,2,3,4,5]
y1= [10,5,4,2,1] #color='blue', marker='o', label='Uncertainty')
y2= [1,2,4,8,10] # , color='orange', marker='o', label='skill')
plt.legend(loc=(0.2,0.9),shadow=True,ncol=2)
plt.plot(x,y1,marker='s')
plt.plot(x,y2,marker='s')
plt.xlabel('X-Axis',labelpad=10)
plt.ylabel('Y-Axis',labelpad=10)
plt.fill_between(x[1:4],y1[1:4],y2[1:4], color='lightgreen', alpha=0.5)
plt.show()
plt.savefig('ch0201_02.png')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ####**예제 03**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_03`로 저장하세요
#
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-3.PNG?raw=true width=400>
# </p>

# %%
x = [1,2,3,4,5]
y1= [10,5,4,2,1] #color='blue', marker='o', label='Uncertainty')
y2= [1,2,4,8,10] # , color='orange', marker='o', label='skill')
#plt.legend(loc=(0.2,0.9),shadow=True,ncol=2)
#plt.plot([1,2,3,4,5],[10,5,4,2,1], marker='s')
#plt.plot([1,2,3,4,5],[1,2,4,8,10], marker='s')
plt.plot(x,y1,marker='s',label='Uncertainty')
plt.plot(x,y2,marker='s',label='Skill')
plt.xlabel('X-Axis',labelpad=11,fontdict={'family': 'serif', 'color': '#17becf', 'weight': 'bold', 'size': 15})
plt.ylabel('Y-Axis',labelpad=11,fontdict={'family': 'serif', 'color': '#17becf', 'weight': 'bold', 'size': 15})
plt.legend(loc=(0.25,0.9),ncol=2)
plt.axis([0,6,0,14])
#plt.xlabel('X-Axis', labelpad=15)
#plt.ylabel('Y-Axis', labelpad=15)
#plt.show()
plt.savefig('ch0201_03.png')

# %% [markdown]
# ####**예제 04**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_04`로 저장하세요
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-4.PNG?raw=true width=400>
# </p>

# %%
x = [1,2,3,4,5]
y1= [10,5,4,2,1] #color='blue', marker='o', label='Uncertainty')
y2= [1,2,4,8,10] # , color='orange', marker='o', label='skill')
#plt.legend(loc=(0.2,0.9),shadow=True,ncol=2)
#plt.plot([1,2,3,4,5],[10,5,4,2,1], marker='s')
#plt.plot([1,2,3,4,5],[1,2,4,8,10], marker='s')
plt.plot(x,y1,marker='s',label='Uncertainty')
plt.plot(x,y2,marker='s',label='Skill',color='hotpink')
plt.xlabel('X-Axis',labelpad=11)
plt.ylabel('Y-Axis',labelpad=11)
plt.legend(loc=(0.35,0.85),ncol=1)
plt.axis([0.5,5.5,0,10.5])
plt.grid()
plt.title('my plot')
plt.savefig('ch0201_04.png')

# %% [markdown]
# ####**예제 05**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_05`로 저장하세요
#
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-5.PNG?raw=true width=400>
# </p>

# %%
x = [1,2,3,4,5]
y1= [10,5,4,2,1] #color='blue', marker='o', label='Uncertainty')
y2= [1,2,4,8,10] # , color='orange', marker='o', label='skill')
#plt.legend(loc=(0.2,0.9),shadow=True,ncol=2)
#plt.plot([1,2,3,4,5],[10,5,4,2,1], marker='s')
#plt.plot([1,2,3,4,5],[1,2,4,8,10], marker='s')
plt.plot(x,y1,label='Uncertainty',  linestyle='dashed',linewidth="10")
plt.plot(x,y2,marker='*',markersize=30,label='Skill',color='hotpink', linestyle='solid',linewidth="10")
plt.xlabel('X-Axis',labelpad=11,fontdict={'color':'k','weight':'bold','size':15})
plt.ylabel('Y-Axis',labelpad=11,fontdict={'color':'k','weight':'bold','size':15})
plt.legend(loc=(0.35,0.85),ncol=1)
plt.axis([0.5,5.5,0,10.5])

plt.tick_params(axis='x',direction='out',length=10,pad=10,labelsize=14,width=5,labelcolor='black',top=False)
plt.tick_params(axis='y',direction='out',length=10,pad=10,labelsize=14,width=5,labelcolor='black')
plt.grid()
plt.title('my plot',loc='left')
plt.savefig('ch0201_05.png')

# %% [markdown]
# ####**예제 06**
#
# 본인 스타일 대로 데이터를 잘 나타내도록 그림을 그리고 `ch0201_06`으로 저장하세요.

# %%
x = [1,2,3,4,5]
y1= [10,5,4,2,1] #color='blue', marker='o', label='Uncertainty')
y2= [1,2,4,8,10] # , color='orange', marker='o', label='skill')
#plt.legend(loc=(0.2,0.9),shadow=True,ncol=2)
#plt.plot([1,2,3,4,5],[10,5,4,2,1], marker='s')
#plt.plot([1,2,3,4,5],[1,2,4,8,10], marker='s')
plt.plot(x,y1,label='Uncertainty',  linestyle='dashed',linewidth="10")
plt.plot(x,y2,marker='*',markersize=30,label='Skill',color='hotpink', linestyle='solid',linewidth="10")
plt.xlabel('X-Axis',labelpad=11,fontdict={'color':'k','weight':'bold','size':15})
plt.ylabel('Y-Axis',labelpad=11,fontdict={'color':'k','weight':'bold','size':15})
plt.legend(loc=(0.35,0.85),ncol=1)
plt.axis([0.5,5.5,0,10.5])

plt.tick_params(axis='x',direction='out',length=10,pad=10,labelsize=14,width=5,labelcolor='black',top=False)
plt.tick_params(axis='y',direction='out',length=10,pad=10,labelsize=14,width=5,labelcolor='black')
plt.grid()
plt.title('my plot',loc='left')
plt.savefig('ch0201_06.png')
